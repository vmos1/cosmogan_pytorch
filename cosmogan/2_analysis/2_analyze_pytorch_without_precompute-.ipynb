# %% [markdown]
# # Analyze results with histograms and plots made from scratch
# October 27, 2020

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import subprocess as sp
import sys
import os
import glob
import pickle 

from matplotlib.colors import LogNorm, PowerNorm, Normalize
from ipywidgets import *

# %%
# %matplotlib widget

# %%
sys.path.append('/global/u1/v/vpa/project/jpt_notebooks/Cosmology/Cosmo_GAN/repositories/lbann_cosmogan/3_analysis/')
from modules_image_analysis import *

# %%
### Transformation functions for image pixel values
def f_transform(x):
    return 2.*x/(x + 4.) - 1.

def f_invtransform(s):
    return 4.*(1. + s)/(1. - s)

# %% [markdown]
# ## Read data

# %%
# main_dir='/global/cfs/cdirs/m3363/vayyar/cosmogan_data/results_from_other_code/pytorch/results/128sq/'
# results_dir=main_dir+'20201002_064327'

# %%
dict1={'128':'/global/cfs/cdirs/m3363/vayyar/cosmogan_data/results_from_other_code/pytorch/results/128sq/',
      '512':'/global/cfs/cdirs/m3363/vayyar/cosmogan_data/results_from_other_code/pytorch/results/512sq/'}

u=interactive(lambda x: dict1[x], x=Select(options=dict1.keys()))
# display(u)

# %%
# parent_dir=u.result
parent_dir=dict1['128']
dir_lst=[i.split('/')[-1] for i in glob.glob(parent_dir+'20*')]
w=interactive(lambda x: x, x=Dropdown(options=dir_lst))
display(w)
# Out:
# interactive(children=(Dropdown(description='x', options=('20201106_061659_full_loss_b512_chkpt2', '20201002_07…

# %%
result=w.result
result_dir=parent_dir+result
print(result_dir)
# Out:
# /global/cfs/cdirs/m3363/vayyar/cosmogan_data/results_from_other_code/pytorch/results/128sq/20201105_101509_full_loss_b512_chkpt2

# %%
# ### Read loss data
# with open (result_dir+'/metrics.pickle','rb') as f:
#     metrics_dict=pickle.load(f)

# metrics_dict

# df_metrics=pd.DataFrame([])
# for key in metrics_dict.keys(): df_metrics[key]=metrics_dict[key]
# df_metrics['step']=np.arange(df_metrics.shape[0])
# # df_metrics=df_metrics.dropna()

# %% [markdown]
# ## Plot Losses

# %%
df_metrics=pd.read_pickle(result_dir+'/df_metrics.pkle').astype(np.float64)

# %%
df_metrics.step.values.shape,df_metrics.G_full.values.shape
# Out:
# ((7801,), (7801,))

# %%
df_metrics.head(10)
# Out:
#    step       Dreal        Dfake        Dfull  G_adv     G_full  spec_loss  \
# 0   0.0  114.471611  8915.812500  9030.284180    0.0  54.768456  54.768456
# 1   1.0  118.411423  8865.130859  8983.541992    0.0  50.073792  50.073792
# 2   2.0  119.276917  8556.442383  8675.719727    0.0  48.563263  48.563263
# 3   3.0  126.231918  8184.251465  8310.483398    0.0  48.473293  48.473293
# 4   4.0  117.809799  7872.899414  7990.708984    0.0  48.270676  48.270676
# 5   5.0  118.518463  7598.492188  7717.010742    0.0  54.709717  54.709717
# 6   6.0  113.817719  7581.412109  7695.229980    0.0  48.465782  48.465782
# 7   7.0  122.003082  7375.926758  7497.929688    0.0  49.310265  49.310265
# 8   8.0  122.143036  7193.630859  7315.773926    0.0  48.607452  48.607452
# 9   9.0  114.710876  7081.482422  7196.193359    0.0  48.546463  48.546463
#
#    hist_loss   spec_chi  hist_chi          D(x)       D_G_z1       D_G_z2  \
# 0  -4.135537        NaN       NaN  10249.712891  9006.829102  8395.084961
# 1  -4.387058  54.245193 -3.893679  10240.910156  8976.296875  8398.788086
# 2   3.417511  51.628384 -4.179056  10229.566406  8632.062500  8108.893555
# 3   1.607290  53.301186 -4.119776  10226.039062  8318.550781  7776.613770
# 4   4.137031  50.134312 -6.217584  10230.264648  7980.061035  7720.972656
# 5  -4.158140  64.925827 -3.894559  10218.572266  7636.944336  7227.654785
# 6   4.049687  48.178017  4.013538  10208.734375  7637.144043  7296.676270
# 7  -5.392483  50.809700 -4.524550  10216.093750  7438.209473  7119.696289
# 8   4.033447  48.598534  4.110394  10206.393555  7371.621094  6982.899414
# 9   3.985491  48.554306  4.046769  10196.338867  7165.819824  6816.043945
#
#    train_time
# 0   18.195894
# 1    1.005289
# 2    0.700648
# 3    0.696089
# 4    0.690963
# 5    0.700361
# 6    0.697605
# 7    0.696872
# 8    0.698492
# 9    0.698906

# %%
df_metrics[df_metrics.step%50==0].head(10)
# Out:
#       step       Dreal        Dfake        Dfull  G_adv     G_full  spec_loss  \
# 0      0.0  114.471611  8915.812500  9030.284180    0.0  54.768456  54.768456
# 50    50.0  111.464218  3620.975098  3732.439209    0.0  47.429710  47.429710
# 100  100.0  126.874237  2276.921875  2403.796143    0.0  45.862206  45.862206
# 150  150.0  108.947708  1653.378174  1762.325928    0.0  45.403873  45.403873
# 200  200.0   89.919693  4264.954102  4354.874023    0.0  43.179028  43.179028
# 250  250.0  101.930138  3746.349609  3848.279785    0.0  42.339798  42.339798
# 300  300.0  101.978188  3412.606934  3514.585205    0.0  44.432457  44.432457
# 350  350.0   92.210159  3096.897461  3189.107666    0.0  42.296989  42.296989
# 400  400.0   70.325165  2336.987549  2407.312744    0.0  46.557976  46.557976
# 450  450.0   73.151161  1828.242676  1901.393799    0.0  45.723385  45.723385
#
#      hist_loss   spec_chi  hist_chi          D(x)       D_G_z1       D_G_z2  \
# 0    -4.135537        NaN       NaN  10249.712891  9006.829102  8395.084961
# 50    3.885450  47.454475  3.914173   9896.613281  3754.934326  3581.110352
# 100   3.857056  45.707615  1.889703   9411.240234  2281.026123  2192.729980
# 150   2.077824  45.059814  1.533966   9028.542969  1655.355957  1626.256104
# 200   3.402302  42.260860  3.206932   8735.157227  4332.997559  4282.844238
# 250   3.683445  42.729767  1.500444   8480.214844  3794.085449  3781.409912
# 300   3.758322  42.861893  3.547242   8112.753418  3440.433105  3427.039062
# 350   3.490838  42.927017  3.589836   7724.855469  3132.860840  3089.584961
# 400   3.054752  46.574219  3.253120   7341.668945  2343.968018  2293.749023
# 450   3.314147  46.115612  3.295486   6890.826172  1855.320190  1787.207275
#
#      train_time
# 0     18.195894
# 50     0.718791
# 100    0.778228
# 150    0.721906
# 200    0.705493
# 250    0.781412
# 300    0.714873
# 350    0.721644
# 400    0.728086
# 450    0.732604

# %%
def f_plot_metrics(df,col_list):
    
    plt.figure()
    for key in col_list:
        plt.plot(df_metrics[key],label=key,marker='*',linestyle='')
    plt.legend()
    
#     col_list=list(col_list)
#     df.plot(kind='line',x='step',y=col_list)
    
# f_plot_metrics(df_metrics,['spec_chi','hist_chi'])

interact_manual(f_plot_metrics,df=fixed(df_metrics), col_list=SelectMultiple(options=df_metrics.columns.values))
# Out:
# interactive(children=(SelectMultiple(description='col_list', options=('step', 'Dreal', 'Dfake', 'Dfull', 'G_ad…
# <function __main__.f_plot_metrics(df, col_list)>

# %%
chi=df_metrics.dropna().quantile(q=0.05,axis=0)['hist_chi']
print(chi)
df_metrics[df_metrics['hist_chi']<=chi].sort_values(by=['hist_chi']).head(10)
# Out:
# -9.007347297668458
#         step     Dreal      Dfake      Dfull      G_adv     G_full  spec_loss  \
# 4111  4111.0  0.180657   1.004692   1.185349  17.542948  61.783760  44.240814
# 7253  7253.0  0.210032   0.286707   0.496739  13.164577  58.220982  45.056404
# 5218  5218.0  0.180844   0.266540   0.447383   6.415269  50.158932  43.743664
# 7392  7392.0  0.273038   0.936384   1.209422  17.846178  61.951538  44.105362
# 5849  5849.0  0.248449   0.169845   0.418294   8.210242  54.041904  45.831661
# 5918  5918.0  0.199154   0.678959   0.878114  17.006886  59.290573  42.283688
# 2424  2424.0  0.945678  17.189735  18.135414  43.324104  90.251907  46.927807
# 5503  5503.0  0.909907   0.407550   1.317457  27.760729  73.813934  46.053204
# 6586  6586.0  0.145068   0.835840   0.980908  18.370718  63.064293  44.693577
# 7142  7142.0  5.995208   0.444634   6.439841  11.739789  56.189178  44.449390
#
#       hist_loss   spec_chi   hist_chi       D(x)     D_G_z1     D_G_z2  \
# 4111  -6.776525  45.015686 -13.529433  17.018934  -5.492321 -17.525570
# 7253  -6.760732  43.584850 -13.431226  13.359855 -14.817257 -13.117199
# 5218  -7.742609  44.857414 -13.323910  18.781128 -12.234115  -5.796060
# 7392  -7.058538  43.673935 -13.067677  12.852794 -12.020864 -17.846077
# 5849  -5.838941  46.605865 -13.013369  11.813009 -10.729334  -8.107081
# 5918  -7.255834  43.412193 -12.822334  14.573029  -6.054008 -17.006720
# 2424  -5.189800  45.520706 -12.732144  38.170746 -13.361099 -35.112228
# 5503  -6.138976  46.640137 -12.702191  11.111387 -20.704468 -27.741169
# 6586  -9.579252  44.706341 -12.445964  14.151506  -2.955996 -18.366169
# 7142  -8.064925  44.210270 -12.400540  -4.169171 -24.985229  -9.086131
#
#       train_time
# 4111    0.703311
# 7253    0.702811
# 5218    0.728217
# 7392    0.728794
# 5849    0.695900
# 5918    0.722994
# 2424    0.719564
# 5503    0.720209
# 6586    0.731208
# 7142    0.747991

# %%
display(df_metrics.sort_values(by=['hist_chi']).head(8))
display(df_metrics.sort_values(by=['spec_chi']).head(8))
# Out:
#         step     Dreal      Dfake      Dfull      G_adv     G_full  spec_loss  \
# 4111  4111.0  0.180657   1.004692   1.185349  17.542948  61.783760  44.240814
# 7253  7253.0  0.210032   0.286707   0.496739  13.164577  58.220982  45.056404
# 5218  5218.0  0.180844   0.266540   0.447383   6.415269  50.158932  43.743664
# 7392  7392.0  0.273038   0.936384   1.209422  17.846178  61.951538  44.105362
# 5849  5849.0  0.248449   0.169845   0.418294   8.210242  54.041904  45.831661
# 5918  5918.0  0.199154   0.678959   0.878114  17.006886  59.290573  42.283688
# 2424  2424.0  0.945678  17.189735  18.135414  43.324104  90.251907  46.927807
# 5503  5503.0  0.909907   0.407550   1.317457  27.760729  73.813934  46.053204
#
#       hist_loss   spec_chi   hist_chi       D(x)     D_G_z1     D_G_z2  \
# 4111  -6.776525  45.015686 -13.529433  17.018934  -5.492321 -17.525570
# 7253  -6.760732  43.584850 -13.431226  13.359855 -14.817257 -13.117199
# 5218  -7.742609  44.857414 -13.323910  18.781128 -12.234115  -5.796060
# 7392  -7.058538  43.673935 -13.067677  12.852794 -12.020864 -17.846077
# 5849  -5.838941  46.605865 -13.013369  11.813009 -10.729334  -8.107081
# 5918  -7.255834  43.412193 -12.822334  14.573029  -6.054008 -17.006720
# 2424  -5.189800  45.520706 -12.732144  38.170746 -13.361099 -35.112228
# 5503  -6.138976  46.640137 -12.702191  11.111387 -20.704468 -27.741169
#
#       train_time
# 4111    0.703311
# 7253    0.702811
# 5218    0.728217
# 7392    0.728794
# 5849    0.695900
# 5918    0.722994
# 2424    0.719564
# 5503    0.720209
#         step     Dreal     Dfake     Dfull      G_adv     G_full  spec_loss  \
# 5771  5771.0  3.678257  0.230114  3.908370   7.144772  49.170757  42.025986
# 5639  5639.0  0.276405  2.465780  2.742185  28.474405  67.884056  39.409653
# 4147  4147.0  0.569512  0.335319  0.904831  11.327412  54.928070  43.600658
# 7354  7354.0  6.576788  0.456983  7.033771  15.060838  56.029114  40.968277
# 6513  6513.0  0.351741  0.215028  0.566769  18.310690  60.644737  42.334045
# 5774  5774.0  0.224598  0.187667  0.412265  15.971888  57.041031  41.069141
# 7094  7094.0  0.405247  0.224976  0.630222   9.944370  51.194897  41.250526
# 3670  3670.0  0.384674  0.240380  0.625054  10.455601  53.843441  43.387840
#
#       hist_loss   spec_chi  hist_chi       D(x)     D_G_z1     D_G_z2  \
# 5771  -6.621045  39.165359 -8.709846  -0.994909 -19.889162  -6.218153
# 5639 -12.210136  39.205215 -6.550752  19.286707   0.040510 -28.474405
# 4147  -4.525765  40.088360 -4.703741  12.382410 -17.191921 -10.762531
# 7354 -11.156568  40.135521 -5.936697  -5.958675 -32.712009 -11.961940
# 6513  -7.003168  40.217812 -8.235284  10.665041 -17.003372 -18.307838
# 5774  -8.970101  40.293442 -7.154328  13.118936 -11.411959 -15.970069
# 7094  -4.214797  40.312019 -4.164631   9.031563  -6.974238  -9.925335
# 3670 -10.024461  40.337242 -8.106384  16.960453 -15.220673  -9.922001
#
#       train_time
# 5771    0.696007
# 5639    0.737701
# 4147    0.703911
# 7354    0.725077
# 6513    0.727791
# 5774    0.705632
# 7094    0.725108
# 3670    0.699886

# %% [markdown]
# ## Read stored chi-squares for images

# %%
df=pd.read_pickle(result_dir+'/df_processed.pkle')
df[['epoch','step']]=df[['epoch','step']].astype(int)

chi1=df.quantile(q=0.2,axis=0)['chi_1']
chi_spec=df.quantile(q=0.2,axis=0)['chi_spec1']

df[(df.chi_spec1<chi_spec)&(df.chi_1<chi1)].sort_values(by=['chi_spec1','chi_1']).head(10)
# df[df.chi_1<chi1].sort_values(by=['chi_1']).head(5)
# Out:
#       epoch  step img_type                                              fname  \
# 3257     16  6512    train  /global/cfs/cdirs/m3363/vayyar/cosmogan_data/r...
#
[-1.031746031584782, -0.6161616169043975, -0.3...
# 2882  [-1.031746031584782, -0.6161616169043975, -0.3...
#
#                                                spec_val  \
# 3257  [93953.03505231021, 73306.51671702867, 52489.0...
# 3220  [86966.03166779457, 81974.44628665262, 62829.4...
# 3219  [96653.73142038565, 91689.99898664467, 67727.8...
# 2841  [115653.42499650922, 72480.20697305321, 50473....
# 2840  [119378.00663811294, 74434.76869208373, 51027....
# 3065  [91612.13951798435, 76519.04787891512, 55859.3...
# 2866  [86886.34024762688, 64194.956192605, 49554.429...
# 2864  [81631.58876512782, 65275.63524917612, 45306.2...
# 2958  [82279.0129793468, 69581.65797543639, 57023.77...
# 2882  [105228.92117429595, 77485.27954830816, 56574....
#
#                                                spec_err
# 3257  [1905.4781272919513, 1186.6946410604146, 890.4...
# 3220  [1980.7731779812, 1877.046673575215, 1264.8506...
# 3219  [2268.7163184682477, 2172.921241034596, 1427.1...
# 2841  [2124.2888463930094, 1622.839640638661, 1101.4...
# 2840  [2265.3671737103564, 1560.944642176309, 1079.5...
# 3065  [2313.5193967366718, 2126.770943683826, 1565.7...
# 2866  [1764.2786973294237, 939.2125113479152, 658.60...
# 2864  [1429.588001728566, 1011.1090778405517, 676.26...
# 2958  [1942.7580503721238, 1513.8750084730302, 1131....
# 2882  [1729.4889310978572, 1181.1052217147046, 1043....

# %%
df[(df.chi_spec1<chi_spec)&(df.chi_1<chi1)].sort_values(by=['chi_1','chi_spec1']).head(5)
# df[df.chi_spec1<chi_spec].sort_values(by=['chi_spec1']).head(5)
# Out:
#       epoch  step img_type                                              fname  \
# 1863      9  3728    train  /global/cfs/cdirs/m3363/vayyar/cosmogan_data/r...
# 1813      9  3628    train  /global/cfs/cdirs/m3363/vayyar/cosmogan_data/r...
# 2354     12  4708    train  /global/cfs/cdirs/m3363/vayyar/cosmogan_data/r...
# 1844      9  3690    train  /global/cfs/cdirs/m3363/vayyar/cosmogan_data/r...
# 3470     17  6938    train  /global/cfs/cdirs/m3363/vayyar/cosmogan_data/r...
#
#         chi_1a    chi_1b    chi_1c     chi_1     chi_2  chi_imgvar  chi_spec1  \
# 1863  0.058826  0.027307  0.005314  0.091446  0.019260    3.829661   4.580766
# 1813  0.069712  0.025818  0.009415  0.104944  0.034853    4.678008   4.487966
# 2354  0.101248  0.004719  0.000783  0.106750  0.098112    3.643917   3.031556
# 1844  0.058776  0.041172  0.007748  0.107696  0.027094    3.733787   3.851430
# 3470  0.096836  0.009236  0.007180  0.113252  0.053782    4.862042   4.087319
#
#           chi_spec2  num_large  num_vlarge  \
# 1863   85563.597428          1           0
# 1813   77942.184318          1           0
# 2354   43966.383485          0           0
# 1844  106887.405823          0           0
# 3470   48277.301412          0           0
#
#                                                hist_val  \
# 1863  [1.1593304008346508, 0.8395994169532269, 0.283...
# 1813  [1.2042262883253307, 0.8000459534332841, 0.251...
# 2354  [1.2916382733520912, 0.7005449171724712, 0.234...
# 1844  [1.183101075959097, 0.8166705196264852, 0.2687...
# 3470  [1.2050702453940445, 0.7546045382023907, 0.286...
#
#                                                hist_err  \
# 1863  [0.0025769052987120503, 0.001968253248106336, ...
# 1813  [0.0041473054579626144, 0.00362123767260678, 0...
# 2354  [0.002302972726433988, 0.0015275823142740044, ...
# 1844  [0.002914849199885293, 0.002147682276681345, 0...
# 3470  [0.004631338453254029, 0.0035448411252213177, ...
#
#                                        hist_bin_centers  \
# 1863  [-1.031746031584782, -0.6161616169043975, -0.3...
# 1813  [-1.031746031584782, -0.6161616169043975, -0.3...
# 2354  [-1.031746031584782, -0.6161616169043975, -0.3...
# 1844  [-1.031746031584782, -0.6161616169043975, -0.3...
# 3470  [-1.031746031584782, -0.6161616169043975, -0.3...
#
#                                                spec_val  \
# 1863  [103696.91145091783, 60619.016948831224, 51669...
# 1813  [90112.89092809136, 69710.43261115647, 53634.6...
# 2354  [70741.44435636711, 49068.73906571269, 47364.2...
# 1844  [74671.2780673725, 57177.7551068941, 56578.152...
# 3470  [116194.10053479276, 86311.68306072343, 60272....
#
#                                                spec_err
# 1863  [1210.387382069174, 820.9876480633756, 735.068...
# 1813  [1237.8011396353577, 1513.4871652945424, 1234....
# 2354  [1436.6656537288256, 1186.1601638061388, 972.1...
# 1844  [1514.9780796796301, 931.8250783300317, 957.68...
# 3470  [2099.3417364409734, 1430.0577523382271, 959.0...

# %%
step_list=[4111,5771]

print([(j.epoch,j.step) for i,j in df[df.step.isin(step_list)][['epoch','step']].iterrows()])
# Out:
# [(10, 4111), (14, 5771)]

# %%
df_metrics[df_metrics.step.isin(step_list)]
# Out:
#         step     Dreal     Dfake     Dfull      G_adv     G_full  spec_loss  \
# 4111  4111.0  0.180657  1.004692  1.185349  17.542948  61.783760  44.240814
# 5771  5771.0  3.678257  0.230114  3.908370   7.144772  49.170757  42.025986
#
#       hist_loss   spec_chi   hist_chi       D(x)     D_G_z1     D_G_z2  \
# 4111  -6.776525  45.015686 -13.529433  17.018934  -5.492321 -17.525570
# 5771  -6.621045  39.165359  -8.709846  -0.994909 -19.889162  -6.218153
#
#       train_time
# 4111    0.703311
# 5771    0.696007

# %%
df[df.step.isin(step_list)][['epoch','step','chi_1','chi_spec1']]
# Out:
#       epoch  step     chi_1  chi_spec1
# 2055     10  4111  0.146140  16.454871
# 2886     14  5771  0.231337   3.244702

# %%
df[(df.step>1000) & (df.step<1040)][['epoch','step','chi_1','chi_spec1']]
# Out:
#      epoch  step       chi_1   chi_spec1
# 500      2  1002  127.901531  353.254708
# 501      2  1004  121.636240  357.276647
# 502      2  1006  182.195650  376.477805
# 503      2  1008  126.283575  423.944307
# 504      2  1010  199.785339  634.928938
# 505      2  1012  163.469904  802.787346
# 506      2  1014   73.746961  707.222875
# 507      2  1016  106.831801  567.887390
# 508      2  1018   74.958239  419.693757
# 509      2  1020  140.764871  531.696642
# 510      2  1022   92.774445  496.300246
# 511      2  1024  116.035067  700.207667
# 512      2  1026   83.855830  544.235567
# 513      2  1028  111.987763  512.364052
# 514      2  1030  172.918940  432.123048
# 515      2  1032  167.984008  281.897452
# 516      2  1034  170.062736  302.745688
# 517      2  1036   78.770233  300.916935
# 518      2  1038   70.919472  429.894893

# %%
df_metrics.query('step>1000 & step<1040 & step%2==0')
# Out:
#         step      Dreal        Dfake        Dfull       G_adv      G_full  \
# 1002  1002.0  39.542839   651.320618   690.863464    0.000000   49.581238
# 1004  1004.0  34.658211   367.868958   402.527161   73.162216  123.197189
# 1006  1006.0  36.460617   680.616089   717.076721    0.278508   50.818703
# 1008  1008.0  33.938938  1739.310791  1773.249756    0.000000   50.268829
# ## Plot histogram and spectrum

# %%
def f_widget_compare(sample_names,sample_dict,bkgnd_arr,Fig_type='pixel',rescale=True,log_scale=True,bins=25,mode='avg',normalize=True,crop=False):
    '''
    Module to make widget plots for pixel intensity or spectrum comparison for multiple sample sets
    '''
    
    
    if crop: # Crop out large pixel values
        for key in sample_names:
            print(sample_dict[key].shape)
            sample_dict[key]=np.array([arr for arr in sample_dict[key] if np.max(arr)<=0.994])
            print(sample_dict[key].shape)
    
    img_list=[sample_dict[key] for key in sample_names]
    label_list=list(sample_names)
        
    hist_range=(0,0.996)
    
    if rescale: 
        for count,img in enumerate(img_list):
            img_list[count]=f_invtransform(img)
        hist_range=(0,2000)
        bkgnd_arr=f_invtransform(bkgnd_arr)
    
    assert Fig_type in ['pixel','spectrum'],"Invalid mode %s"%(mode)
    
    if Fig_type=='pixel':
        f_compare_pixel_intensity(img_lst=img_list,label_lst=label_list,bkgnd_arr=bkgnd_arr,normalize=normalize,log_scale=log_scale, mode=mode,bins=bins,hist_range=hist_range)
    elif Fig_type=='spectrum':
        f_compare_spectrum(img_lst=img_list,label_lst=label_list,bkgnd_arr=bkgnd_arr,log_scale=log_scale)

# %% [markdown]
# ## Plot spectrum

# %%
dict_samples={}

# %%
# keras image for comparison
f1='/global/cfs/cdirs/m3363/vayyar/cosmogan_data/results_from_other_code/exagan1/run5_fixed_cosmology/models/gen_imgs.npy'
img_2=np.expand_dims(np.load(f1)[:500],axis=1)[:,0,:,:]
dict_samples['keras']=img_2

# %%
# Read input data

fname='/global/cfs/cdirs/m3363/vayyar/cosmogan_data/raw_data/128_square/dataset_2_smoothing_200k/norm_1_train_val.npy'
samples=np.load(fname,mmap_mode='r+')[:2000]
samples=samples[:,0,:,:]
print(samples.shape)
# dict_samples['val input']=samples
# Out:
# (2000, 128, 128)

# %%
for step in step_list:
    fname='*gen_img_epoch-*_step-{0}.npy'.format(step)
    fle=glob.glob(result_dir+'/images/'+fname)[0]
    imgs=np.load(fle)
#     img_list.append(imgs)
#     labels_list.append('Step:',step)
    strg='step:%s'%(step)
    dict_samples[strg]=imgs

# %%
bkgnd=samples

# bins=np.concatenate([np.array([-0.5]),np.arange(0.5,20.5,1),np.arange(20.5,100.5,5),np.arange(100.5,1000.5,50),np.array([2000])]) #bin edges to use
# bins=f_transform(bins)   ### scale to (-1,1) 
bins=50
interact_manual(f_widget_compare,sample_dict=fixed(dict_samples),
                sample_names=SelectMultiple(options=dict_samples.keys()), bkgnd_arr=fixed(bkgnd),
                Fig_type=ToggleButtons(options=['pixel','spectrum']),bins=fixed(bins),mode=['avg','simple'])
# Out:
# interactive(children=(SelectMultiple(description='sample_names', options=('keras', 'step:34800', 'step:44800',…
# <function __main__.f_widget_compare(sample_names, sample_dict, bkgnd_arr, Fig_type='pixel', rescale=True, log_scale=True, bins=25, mode='avg', normalize=True, crop=False)>

# %% [markdown]
# ## Plot images

# %%
f_plot_grid(bkgnd[100:118],cols=6,fig_size=(6,3))
f_plot_grid(dict_samples['step:39400'][40:58],cols=6,fig_size=(6,3))
# Out:
# 3 6
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 3 6
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
